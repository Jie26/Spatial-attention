# %%
import modin.pandas as pd
import numpy as np
import os
import time
# Out:
# 2019-06-02 18:36:46,803	INFO node.py:469 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-06-02_18-36-46_8156/logs.
# 2019-06-02 18:36:46,944	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:34624 to respond...
# 2019-06-02 18:36:47,065	INFO services.py:407 -- Waiting for redis server at 127.0.0.1:20967 to respond...
# 2019-06-02 18:36:47,071	INFO services.py:804 -- Starting Redis shard with 1.66 GB max memory.
# 2019-06-02 18:36:47,091	INFO node.py:483 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-06-02_18-36-46_8156/logs.
# 2019-06-02 18:36:47,095	INFO services.py:1427 -- Starting the Plasma object store with 4.0 GB memory using /dev/shm.
# 2019-06-02 18:36:51,548	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_parquet_columns' with function ID c0b4968ae548eb29942a3720be6d262ba97bd664. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,550	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_parquet_columns' with function ID c0b4968ae548eb29942a3720be6d262ba97bd664. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,550	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_parquet_columns' with function ID c0b4968ae548eb29942a3720be6d262ba97bd664. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,551	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_parquet_columns' with function ID c0b4968ae548eb29942a3720be6d262ba97bd664. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,561	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_csv_with_offset_pandas_on_ray' with function ID 08dd528fa269e2988cbd7ae38c1ee5c8d346c66b. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/generic/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,563	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_csv_with_offset_pandas_on_ray' with function ID 08dd528fa269e2988cbd7ae38c1ee5c8d346c66b. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/generic/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,563	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_csv_with_offset_pandas_on_ray' with function ID 08dd528fa269e2988cbd7ae38c1ee5c8d346c66b. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/generic/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
# 2019-06-02 18:36:51,564	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_csv_with_offset_pandas_on_ray' with function ID 08dd528fa269e2988cbd7ae38c1ee5c8d346c66b. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/generic/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,565	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_hdf_columns' with function ID 6b59b7f2e1fe6468f28fb0f76561ae0ef9aceddf. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,565	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_hdf_columns' with function ID 6b59b7f2e1fe6468f28fb0f76561ae0ef9aceddf. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,565	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_hdf_columns' with function ID 6b59b7f2e1fe6468f28fb0f76561ae0ef9aceddf. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,566	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_feather_columns' with function ID 3e4ae1160cf93e1dd75af5b9d5aafdcdc35b2566. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,567	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_hdf_columns' with function ID 6b59b7f2e1fe6468f28fb0f76561ae0ef9aceddf. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,567	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_feather_columns' with function ID 3e4ae1160cf93e1dd75af5b9d5aafdcdc35b2566. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
# 2019-06-02 18:36:51,568	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_sql_with_limit_offset' with function ID 341eddae5984924ce47775ee9ebe16ce431823b3. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,578	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pandas_on_ray.io_exp._read_sql_with_offset_pandas_on_ray' with function ID 543a5d432098f00a3190723b20ffbf26ff416b85. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,579	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_feather_columns' with function ID 3e4ae1160cf93e1dd75af5b9d5aafdcdc35b2566. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,587	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_sql_with_limit_offset' with function ID 341eddae5984924ce47775ee9ebe16ce431823b3. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,588	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_sql_with_limit_offset' with function ID 341eddae5984924ce47775ee9ebe16ce431823b3. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,589	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pandas_on_ray.io_exp._read_sql_with_offset_pandas_on_ray' with function ID 543a5d432098f00a3190723b20ffbf26ff416b85. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,590	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.partition.deploy_ray_func' with function ID d777316c4841b0f618aa7fa0af3806db53356d8c. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
# 2019-06-02 18:36:51,591	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_feather_columns' with function ID 3e4ae1160cf93e1dd75af5b9d5aafdcdc35b2566. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/ray/pandas_on_ray/io.py", line 5, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,592	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.partition.deploy_ray_func' with function ID d777316c4841b0f618aa7fa0af3806db53356d8c. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,593	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pandas_on_ray.io_exp._read_sql_with_offset_pandas_on_ray' with function ID 543a5d432098f00a3190723b20ffbf26ff416b85. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,594	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.engines.ray.pandas_on_ray.io._read_sql_with_limit_offset' with function ID 341eddae5984924ce47775ee9ebe16ce431823b3. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,594	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.partition.deploy_ray_func' with function ID d777316c4841b0f618aa7fa0af3806db53356d8c. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,595	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pandas_on_ray.io_exp._read_sql_with_offset_pandas_on_ray' with function ID 543a5d432098f00a3190723b20ffbf26ff416b85. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,596	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.partition.deploy_ray_func' with function ID d777316c4841b0f618aa7fa0af3806db53356d8c. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/cloudpickle/cloudpickle.py", line 965, in subimport
#     __import__(name)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
# 2019-06-02 18:36:51,620	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_axis_func' with function ID 8244f7f6142069282a6293a91999b29b7a0f8561. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,621	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_axis_func' with function ID 8244f7f6142069282a6293a91999b29b7a0f8561. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,622	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_axis_func' with function ID 8244f7f6142069282a6293a91999b29b7a0f8561. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,623	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_axis_func' with function ID 8244f7f6142069282a6293a91999b29b7a0f8561. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,623	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_func_between_two_axis_partitions' with function ID f5673a60558aff98a36b176c71a5ce53f13d142a. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,623	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_func_between_two_axis_partitions' with function ID f5673a60558aff98a36b176c71a5ce53f13d142a. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
# 2019-06-02 18:36:51,624	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_func_between_two_axis_partitions' with function ID f5673a60558aff98a36b176c71a5ce53f13d142a. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,624	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.frame.axis_partition.deploy_ray_func_between_two_axis_partitions' with function ID f5673a60558aff98a36b176c71a5ce53f13d142a. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/experimental/engines/pyarrow_on_ray/frame/axis_partition.py", line 5, in <module>
#     from modin.engines.base.frame.axis_partition import BaseFrameAxisPartition
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/engines/base/frame/axis_partition.py", line 1, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,635	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.io._read_csv_with_offset_pyarrow_on_ray' with function ID 2f601470d6de2204728b08314a75fe752b9950ac. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/data_management/utils.py", line 6, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,636	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.io._read_csv_with_offset_pyarrow_on_ray' with function ID 2f601470d6de2204728b08314a75fe752b9950ac. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/data_management/utils.py", line 6, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,636	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.io._read_csv_with_offset_pyarrow_on_ray' with function ID 2f601470d6de2204728b08314a75fe752b9950ac. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/data_management/utils.py", line 6, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,647	ERROR worker.py:1672 -- Failed to unpickle the remote function 'modin.experimental.engines.pyarrow_on_ray.io._read_csv_with_offset_pyarrow_on_ray' with function ID 2f601470d6de2204728b08314a75fe752b9950ac. Traceback:
# Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/function_manager.py", line 416, in fetch_and_register_remote_function
#     function = pickle.loads(serialized_function)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/modin/data_management/utils.py", line 6, in <module>
#     import pandas
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,648	ERROR worker.py:1672 -- Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/import_thread.py", line 132, in fetch_and_execute_function_to_run
#     function({"worker": self.worker})
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 2135, in register_class_for_serialization
#     "worker"].get_serialization_context(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 238, in get_serialization_context
#     _initialize_serialization(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 1148, in _initialize_serialization
#     serialization_context = pyarrow.default_serialization_context()
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 326, in default_serialization_context
#     register_default_serialization_handlers(context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 321, in register_default_serialization_handlers
#     _register_custom_pandas_handlers(serialization_context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 129, in _register_custom_pandas_handlers
#     import pandas as pd
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
# 2019-06-02 18:36:51,648	ERROR worker.py:1672 -- Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/import_thread.py", line 132, in fetch_and_execute_function_to_run
#     function({"worker": self.worker})
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 2135, in register_class_for_serialization
#     "worker"].get_serialization_context(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 238, in get_serialization_context
#     _initialize_serialization(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 1148, in _initialize_serialization
#     serialization_context = pyarrow.default_serialization_context()
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 326, in default_serialization_context
#     register_default_serialization_handlers(context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 321, in register_default_serialization_handlers
#     _register_custom_pandas_handlers(serialization_context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 129, in _register_custom_pandas_handlers
#     import pandas as pd
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,649	ERROR worker.py:1672 -- Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/import_thread.py", line 132, in fetch_and_execute_function_to_run
#     function({"worker": self.worker})
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 2135, in register_class_for_serialization
#     "worker"].get_serialization_context(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 238, in get_serialization_context
#     _initialize_serialization(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 1148, in _initialize_serialization
#     serialization_context = pyarrow.default_serialization_context()
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 326, in default_serialization_context
#     register_default_serialization_handlers(context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 321, in register_default_serialization_handlers
#     _register_custom_pandas_handlers(serialization_context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 129, in _register_custom_pandas_handlers
#     import pandas as pd
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'
#
# 2019-06-02 18:36:51,649	ERROR worker.py:1672 -- Traceback (most recent call last):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/import_thread.py", line 132, in fetch_and_execute_function_to_run
#     function({"worker": self.worker})
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 2135, in register_class_for_serialization
#     "worker"].get_serialization_context(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 238, in get_serialization_context
#     _initialize_serialization(driver_id)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/worker.py", line 1148, in _initialize_serialization
#     serialization_context = pyarrow.default_serialization_context()
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 326, in default_serialization_context
#     register_default_serialization_handlers(context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 321, in register_default_serialization_handlers
#     _register_custom_pandas_handlers(serialization_context)
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/ray/pyarrow_files/pyarrow/serialization.py", line 129, in _register_custom_pandas_handlers
#     import pandas as pd
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 23, in <module>
#     from pandas.compat.numpy import *
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py", line 446, in <module>
#     import typing
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1356, in <module>
#     class Callable(extra=collections_abc.Callable, metaclass=CallableMeta):
#   File "/usr/stud/wangx0/anaconda3/lib/python3.7/site-packages/typing.py", line 1004, in __new__
#     self._abc_registry = extra._abc_registry
# AttributeError: type object 'Callable' has no attribute '_abc_registry'

# %%
# base_path = r'D:\TUM论文工作\第五周工作\数据\数据5'
# base_path = r'/usr/stud/wangx0/storage/slurm/JieW/highd1/tracksenrich'
# files = os.listdir(base_path)
# files.sort(key=lambda x: int(x.split('_')[0]))
# dfs1=[]
# for path in files:
#     full_path = os.path.join(base_path, path)
#     dfs1.append(pd.read_csv(full_path))

# %%
def drivingscenereproduce(df):
    for i in range(df1.shape[0]):
        a=df1.at[i,'frame']
        b1=df1.at[i,'precedingId']
        b2=df1.at[i,'followingId']
        b3=df1.at[i,'leftPrecedingId']
        b4=df1.at[i,'leftAlongsideId']
        b5=df1.at[i, 'leftFollowingId']
        b6=df1.at[i, 'rightPrecedingId']
        b7=df1.at[i,'rightAlongsideId']
        b8=df1.at[i, 'rightFollowingId']
        if b1==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b1)]
            df2.index=[1]
            df1.at[i,'prex']=df2.at[1,'x']
            df1.at[i,'prey']=df2.at[1,'y']
            df1.at[i,'prexVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'preyVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'prexAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'preyAcceleration']=df2.at[1,'yAcceleration']
        if b2==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b2)]
            df2.index=[1]
            df1.at[i,'folx']=df2.at[1,'x']
            df1.at[i,'foly']=df2.at[1,'y']
            df1.at[i,'folxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'folyVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'folxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'folyAcceleration']=df2.at[1,'yAcceleration']   
        if b3==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b3)]
            df2.index=[1]
            df1.at[i,'lprx']=df2.at[1,'x']
            df1.at[i,'lpry']=df2.at[1,'y']
            df1.at[i,'lprxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'lpryVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'lprxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'lpryAcceleration']=df2.at[1,'yAcceleration']  
        if b4==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b4)]
            df2.index=[1]
            df1.at[i,'lalx']=df2.at[1,'x']
            df1.at[i,'laly']=df2.at[1,'y']
            df1.at[i,'lalxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'lalyVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'lalxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'lalyAcceleration']=df2.at[1,'yAcceleration']   
        if b5==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b5)]
            df2.index=[1]
            df1.at[i,'lfox']=df2.at[1,'x']
            df1.at[i,'lfoy']=df2.at[1,'y']
            df1.at[i,'lfoxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'lfoyVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'lfoxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'lfoyAcceleration']=df2.at[1,'yAcceleration']   
        if b6==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b6)]
            df2.index=[1]
            df1.at[i,'rprx']=df2.at[1,'x']
            df1.at[i,'rpry']=df2.at[1,'y']
            df1.at[i,'rprxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'rpryVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'rprxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'rpryAcceleration']=df2.at[1,'yAcceleration']
        if b7==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b7)]
            df2.index=[1]
            df1.at[i,'ralx']=df2.at[1,'x']
            df1.at[i,'raly']=df2.at[1,'y']
            df1.at[i,'ralxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'ralyVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'ralxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'ralyAcceleration']=df2.at[1,'yAcceleration']
        if b8==0:
            pass
            #df1.at[i,['prex','prey','prexVelocity','preyVelocity','prexAcceleration','preyAcceleration']=0
        else:
            df2=df1.loc[(df1['frame'] == a) & (df1['id'] == b8)]
            df2.index=[1]
            df1.at[i,'rfox']=df2.at[1,'x']
            df1.at[i,'rfoy']=df2.at[1,'y']
            df1.at[i,'rfoxVelocity']=df2.at[1,'xVelocity']
            df1.at[i,'rfoyVelocity']=df2.at[1,'yVelocity']
            df1.at[i,'rfoxAcceleration']=df2.at[1,'xAcceleration']
            df1.at[i,'rfoyAcceleration']=df2.at[1,'yAcceleration']

# %%
base_path = r'/usr/stud/wangx0/storage/slurm/JieW/highd1/tracksenrich'
files = os.listdir(base_path)
files.sort(key=lambda x: int(x.split('_')[0]))
for path in files:
    i=0
    t1=time.time()
    full_path = os.path.join(base_path, path)
    df1=pd.read_csv(full_path)
    del df1['Unnamed: 0']
    drivingscenereproduce(df1)
    df1.to_csv(r'/usr/stud/wangx0/storage/slurm/JieW/highd1/scenario/%d_trackscene.csv'%(i+1))
    t2=time.time()
    i=i+1
    print('%d_process time:'%(i+1))
    print(t2-t1)
    break

# %%
# #a=[10]
# num_data=60
# for i in range(num_data):
#     t1=time.time()
#     df1=dfs1[i]
#     del df1['Unnamed: 0']
#     drivingscenereproduce(df1)
#     df1.to_csv(r'/usr/stud/wangx0/storage/slurm/JieW/highd1/scenario/%d_trackscene.csv'%(i+1))
#     t2=time.time()
#     print('%d_process time:'%(i+1))
#     print(t2-t1)
